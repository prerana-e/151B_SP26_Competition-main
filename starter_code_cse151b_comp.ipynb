# %% [markdown]
# # CSE 151B Competition — Starter Notebook
#
# Welcome to the **CSE 151B Spring 2026 Math Reasoning Competition**!
# This notebook walks you through the full pipeline end-to-end:
#
# 1. Setting up the Python environment with `uv`
# 2. Loading the competition dataset
# 3. Running inference with **Qwen3-4B-Thinking** via vLLM (INT8 quantized)
# 4. Scoring responses against ground-truth answers
# 5. Saving results to JSONL for submission
#
# The public dataset (`public.jsonl`) contains questions **with** answers so you can measure accuracy locally.
# The private test set used for the leaderboard does **not** include answers — for that, skip evaluation and submit the raw responses.

# %% [markdown]
# ## 1. Environment Setup
#
# We use [`uv`](https://github.com/astral-sh/uv) for fast, reproducible package management.
#
# The steps below:
# 1. Install `uv` into `~/.local/bin`
# 2. Create a virtual environment at `.venv/`
# 3. Install all required packages (This might take a while)
#
# > **After running this cell, restart the kernel** so that the newly installed packages (especially `vllm` and `transformers`) are picked up by the current Python session.

# %% [markdown]
# ### Comment Out the cell below after first installation.

# %%
# # Install uv
# !wget -qO- https://astral.sh/uv/install.sh | sh.venv/bin/python -m ipykernel install --user --name cse151b --display-name "Python (cse151b)"

# # Create a virtual environment
# !uv venv .venv --seed

# # Install dependencies — this is fast thanks to uv's parallel resolver
# !.venv/bin/python -m pip install sympy numpy transformers vllm tqdm bitsandbytes antlr4-python3-runtime==4.11.1 ipykernel jupyter

# # Install Jupyter Kernel
# !.venv/bin/python -m ipykernel install --user --name cse151b --display-'name "Python (cse151b)"

# print("Done. Restart the kernel before proceeding.")
# print("Selection process: on top right, click on current kernel '(ususally named python)' -> 'select another kernel' -> 'Jupyter Kernel' -> 'Python (cse151b)'.")

# %% [markdown]
# ### Run the cell below every time to activate the installed environment.

# %%
# activate venv after installation. This needs to be run everytime.
# !source ./.venv/bin/activate

# %% [markdown]
# ## 2. Imports & Configuration
#
# All key settings are collected in one place.
# - `DATA_PATH` — public dataset with ground-truth answers (use this to measure accuracy)
# - `OUTPUT_PATH` — where per-question results will be written
# - `GPU_ID` — which GPU to use (update if your machine has a different device index)
# - `MAX_TOKENS` — maximum tokens the model may generate per response

# %%
import json
import os

# ── Configuration ─────────────────────────────────────────────────────────────
MODEL_ID    = "Qwen/Qwen3-4B-Thinking-2507"
GPU_ID      = "0"                    # CUDA_VISIBLE_DEVICES
DATA_PATH   = "data/public.jsonl"
OUTPUT_PATH = "results/starter_results.jsonl"
MAX_TOKENS  = 32768

os.environ["CUDA_VISIBLE_DEVICES"] = GPU_ID

import re
import sys
from pathlib import Path
from typing import Optional

from transformers import AutoTokenizer
from vllm import LLM, SamplingParams
from tqdm import tqdm

# %% [markdown]
# ## 3. Load the Dataset
#
# The dataset is stored as newline-delimited JSON (`.jsonl`). Each line is one question with the following fields:
#
# | Field | Description |
# |---|---|
# | `id` | Unique question identifier |
# | `question` | Problem statement |
# | `options` | List of answer choices — present for **MCQ**, absent for **free-form** |
# | `answer` | Ground-truth answer (letter for MCQ, value/list for free-form) |

# %%
data = [json.loads(line) for line in open(DATA_PATH)]

n_mcq  = sum(bool(d.get("options")) for d in data)
n_free = sum(not d.get("options")   for d in data)
print(f"Loaded {len(data)} questions  ({n_mcq} MCQ, {n_free} free-form)")

# Preview one MCQ and one free-form item
mcq_sample  = next(d for d in data if d.get("options"))
free_sample = next(d for d in data if not d.get("options"))

print("\n── MCQ sample ──")
print(json.dumps(mcq_sample, indent=2))
print("\n── Free-form sample ──")
print(json.dumps(free_sample, indent=2))
# Out:
# Loaded 1126 questions  (375 MCQ, 751 free-form)
#
# ── MCQ sample ──
# {
#   "question": "$int_{-infty}^{+infty} frac{a^{3/2}}{s^2+a^2} ds = $",
#   "options": [
#     "$0$",
#     "$frac{1}{a}$",
#     "$frac{3}{a}$",
#     "$frac{1}{2a^2}$",
#     "$frac{1}{2a}$",
#     "$frac{2}{a}$",
#     "$2a$",
#     "$frac{3}{2a}$",
#     "$frac{3}{2a^2}$",
#     "$frac{1}{a^2}$"
#   ],
#   "answer": "F",
#   "id": 1
# }
#
# ── Free-form sample ──
# {
#   "question": "Find the sum of the first $325$ positive even whole numbers. Sum: [ANS]",
#   "answer": [
#     "325*(1+325)"
#   ],
#   "id": 0
# }

# %% [markdown]
# ## 4. Prompt Construction
#
# We use two system prompts depending on the question type:
#
# - **MCQ** — the model must select the best answer letter and wrap it in `\boxed{}`
# - **Free-form** — the model solves step-by-step and puts the final answer in `\boxed{}`
#
# `build_prompt()` returns the appropriate `(system, user)` pair for each item.

# %%
SYSTEM_PROMPT_MATH = (
    "You are an expert mathematician. Solve the problem step-by-step. "
    "Put your final answer inside \\boxed{}. "
    "If the problem has multiple sub-answers, separate them by commas inside a single \\boxed{}, "
    "e.g. \\boxed{3, 7}."
)

SYSTEM_PROMPT_MCQ = (
    "You are an expert mathematician. "
    "Read the problem and the answer choices below, then select the single best answer. "
    "Output ONLY the letter of your chosen option inside \\boxed{}, e.g. \\boxed{C}."
)


def build_prompt(question: str, options: Optional[list]) -> tuple[str, str]:
    """Return (system_prompt, user_prompt) for a question."""
    if options:
        labels    = [chr(65 + i) for i in range(len(options))]
        opts_text = "\n".join(f"{lbl}. {opt.strip()}" for lbl, opt in zip(labels, options))
        return SYSTEM_PROMPT_MCQ, f"{question}\n\nOptions:\n{opts_text}"
    return SYSTEM_PROMPT_MATH, question


# Verify with samples
for label, item in [("MCQ", mcq_sample), ("Free-form", free_sample)]:
    sys_p, usr_p = build_prompt(item["question"], item.get("options"))
    print(f"── {label} user prompt (first 200 chars) ──")
    print(usr_p[:200], "...\n")
# Out:
# ── MCQ user prompt (first 200 chars) ──
# $int_{-infty}^{+infty} frac{a^{3/2}}{s^2+a^2} ds = $
#
# Options:
# A. $0$
# B. $frac{1}{a}$
# C. $frac{3}{a}$
# D. $frac{1}{2a^2}$
# E. $frac{1}{2a}$
# F. $frac{2}{a}$
# G. $2a$
# H. $frac{3}{2a}$
# I. $frac{3}{2a^2}$
# J. ...
#
# ── Free-form user prompt (first 200 chars) ──
# Find the sum of the first $325$ positive even whole numbers. Sum: [ANS] ...

# %% [markdown]
# ## 5. Load Model with vLLM (for general case, vLLM is faster)
#
# We load **Qwen3-4B-Thinking-2507** with **INT8 quantization** via BitsAndBytes.
# Setting `load_format="bitsandbytes"` tells vLLM to apply on-the-fly INT8 weight quantization, roughly halving GPU memory usage compared to BF16.
#
# Key parameters:
# - `gpu_memory_utilization` — fraction of GPU VRAM reserved for the model and KV cache
# - `max_model_len` — maximum sequence length (prompt + generation)
# - `max_num_seqs` — maximum number of sequences processed in parallel

# %%
import os
os.environ["VLLM_USE_FLASHINFER_SAMPLER"] = "0"

tokenizer = AutoTokenizer.from_pretrained(MODEL_ID)
tokenizer.pad_token = tokenizer.eos_token

llm = LLM(
    model=MODEL_ID,
    quantization="bitsandbytes",
    load_format="bitsandbytes",
    enable_prefix_caching=False,
    gpu_memory_utilization=0.50,
    max_model_len=16384,
    trust_remote_code=True,
    max_num_seqs=256,
    max_num_batched_tokens=32768,
)

sampling_params = SamplingParams(
    max_tokens=MAX_TOKENS,
    temperature=0.6,
    top_p=0.95,
    top_k=20,
    min_p=0.0,
    presence_penalty=0.0,
    repetition_penalty=1.0,
)

print("Model loaded.")
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# INFO 05-25 19:07:31 [utils.py:240] non-default args: {'trust_remote_code': True, 'load_format': 'bitsandbytes', 'max_model_len': 16384, 'enable_prefix_caching': False, 'gpu_memory_utilization': 0.5, 'max_num_batched_tokens': 32768, 'max_num_seqs': 256, 'disable_log_stats': True, 'quantization': 'bitsandbytes', 'model': 'Qwen/Qwen3-4B-Thinking-2507'}
# INFO 05-25 19:07:31 [model.py:568] Resolved architecture: Qwen3ForCausalLM
# INFO 05-25 19:07:31 [model.py:1697] Using max model len 16384
# INFO 05-25 19:07:31 [scheduler.py:239] Chunked prefill is enabled with max_num_batched_tokens=32768.
# INFO 05-25 19:07:32 [vllm.py:886] Asynchronous scheduling is enabled.
# INFO 05-25 19:07:32 [kernel.py:212] Final IR op priority after setting platform defaults: IrOpPriorityConfig(rms_norm=['native'], fused_add_rms_norm=['native'])
# (EngineCore pid=13461) INFO 05-25 19:07:34 [core.py:109] Initializing a V1 LLM engine (v0.21.0) with config: model='Qwen/Qwen3-4B-Thinking-2507', speculative_config=None, tokenizer='Qwen/Qwen3-4B-Thinking-2507', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, tokenizer_revision=None, trust_remote_code=True, dtype=torch.bfloat16, max_seq_len=16384, download_dir=None, load_format=bitsandbytes, tensor_parallel_size=1, pipeline_parallel_size=1, data_parallel_size=1, decode_context_parallel_size=1, dcp_comm_backend=ag_rs, disable_custom_all_reduce=False, quantization=bitsandbytes, quantization_config=None, enforce_eager=False, enable_return_routed_experts=False, kv_cache_dtype=auto, device_config=cuda, structured_outputs_config=StructuredOutputsConfig(backend='auto', disable_any_whitespace=False, disable_additional_properties=False, reasoning_parser='', reasoning_parser_plugin='', enable_in_reasoning=False), observability_config=ObservabilityConfig(show_hidden_metrics_for_version=None, otlp_traces_endpoint=None, collect_detailed_traces=None, kv_cache_metrics=False, kv_cache_metrics_sample=0.01, cudagraph_metrics=False, enable_layerwise_nvtx_tracing=False, enable_mfu_metrics=False, enable_mm_processor_stats=False, enable_logging_iteration_details=False), seed=0, served_model_name=Qwen/Qwen3-4B-Thinking-2507, enable_prefix_caching=False, enable_chunked_prefill=True, pooler_config=None, compilation_config={'mode': <CompilationMode.VLLM_COMPILE: 3>, 'debug_dump_path': None, 'cache_dir': '', 'compile_cache_save_format': 'binary', 'backend': 'inductor', 'custom_ops': ['none'], 'ir_enable_torch_wrap': True, 'splitting_ops': ['vllm::unified_attention_with_output', 'vllm::unified_mla_attention_with_output', 'vllm::mamba_mixer2', 'vllm::mamba_mixer', 'vllm::short_conv', 'vllm::linear_attention', 'vllm::plamo2_mamba_mixer', 'vllm::gdn_attention_core', 'vllm::gdn_attention_core_xpu', 'vllm::olmo_hybrid_gdn_full_forward', 'vllm::kda_attention', 'vllm::sparse_attn_indexer', 'vllm::rocm_aiter_sparse_attn_indexer', 'vllm::deepseek_v4_attention', 'vllm::unified_kv_cache_update', 'vllm::unified_mla_kv_cache_update'], 'compile_mm_encoder': False, 'cudagraph_mm_encoder': False, 'encoder_cudagraph_token_budgets': [], 'encoder_cudagraph_max_vision_items_per_batch': 0, 'encoder_cudagraph_max_frames_per_batch': None, 'compile_sizes': [], 'compile_ranges_endpoints': [32768], 'inductor_compile_config': {'enable_auto_functionalized_v2': False, 'size_asserts': False, 'alignment_asserts': False, 'scalar_asserts': False, 'combo_kernels': True, 'benchmark_combo_kernel': True}, 'inductor_passes': {}, 'cudagraph_mode': <CUDAGraphMode.FULL_AND_PIECEWISE: (2, 1)>, 'cudagraph_num_of_warmups': 1, 'cudagraph_capture_sizes': [1, 2, 4, 8, 16, 24, 32, 40, 48, 56, 64, 72, 80, 88, 96, 104, 112, 120, 128, 136, 144, 152, 160, 168, 176, 184, 192, 200, 208, 216, 224, 232, 240, 248, 256, 272, 288, 304, 320, 336, 352, 368, 384, 400, 416, 432, 448, 464, 480, 496, 512], 'cudagraph_copy_inputs': False, 'cudagraph_specialize_lora': True, 'use_inductor_graph_partition': False, 'pass_config': {'fuse_norm_quant': False, 'fuse_act_quant': False, 'fuse_attn_quant': False, 'enable_sp': False, 'fuse_gemm_comms': False, 'fuse_allreduce_rms': False, 'fuse_act_padding': False}, 'max_cudagraph_capture_size': 512, 'dynamic_shapes_config': {'type': <DynamicShapesType.BACKED: 'backed'>, 'evaluate_guards': False, 'assume_32_bit_indexing': False}, 'local_cache_dir': None, 'fast_moe_cold_start': False, 'static_all_moe_layers': []}, kernel_config=KernelConfig(ir_op_priority=IrOpPriorityConfig(rms_norm=['native'], fused_add_rms_norm=['native']), enable_flashinfer_autotune=False, moe_backend='auto')
# (EngineCore pid=13461) INFO 05-25 19:07:34 [parallel_state.py:1410] world_size=1 rank=0 local_rank=0 distributed_init_method=tcp://10.37.32.159:39079 backend=nccl
# (EngineCore pid=13461) INFO 05-25 19:07:34 [parallel_state.py:1723] rank 0 in world size 1 is assigned as DP rank 0, PP rank 0, PCP rank 0, TP rank 0, EP rank N/A, EPLB rank N/A
# (EngineCore pid=13461) INFO 05-25 19:07:36 [topk_topp_sampler.py:45] Using FlashInfer for top-p & top-k sampling.
# (EngineCore pid=13461) INFO 05-25 19:07:36 [gpu_model_runner.py:4857] Starting to load model Qwen/Qwen3-4B-Thinking-2507...
# (EngineCore pid=13461) INFO 05-25 19:07:37 [cuda.py:372] Using FLASH_ATTN attention backend out of potential backends: ['FLASH_ATTN', 'FLASHINFER', 'TRITON_ATTN', 'FLEX_ATTENTION'].
# (EngineCore pid=13461) INFO 05-25 19:07:37 [flash_attn.py:641] Using FlashAttention version 2
# (EngineCore pid=13461) INFO 05-25 19:07:38 [bitsandbytes_loader.py:786] Loading weights with BitsAndBytes quantization. May take a while ...
# (EngineCore pid=13461) INFO 05-25 19:07:38 [weight_utils.py:938] Filesystem type for checkpoints: OVERLAY. Checkpoint size: 7.49 GiB. Available RAM: 418.09 GiB.
# (EngineCore pid=13461) INFO 05-25 19:07:38 [weight_utils.py:961] Auto-prefetch is disabled because the filesystem (OVERLAY) is not a recognized network FS (NFS/Lustre). If you want to force prefetching, start vLLM with --safetensors-load-strategy=prefetch.
# Loading safetensors checkpoint shards:   0% Completed | 0/3 [00:00<?, ?it/s]
# (EngineCore pid=13461) /home/prgowda/private/151B_SP26_Competition-main/.venv/lib/python3.14/site-packages/bitsandbytes/backends/cuda/ops.py:213: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
# (EngineCore pid=13461)   torch._check_is_size(blocksize)
# (EngineCore pid=13461) INFO 05-25 19:07:40 [gpu_model_runner.py:4959] Model loading took 2.71 GiB memory and 3.065595 seconds
# (EngineCore pid=13461) INFO 05-25 19:07:44 [backends.py:1089] Using cache directory: /tmp/xdg-cache/vllm/torch_compile_cache/44a82a9ac8/rank_0_0/backbone for vLLM's torch.compile
# (EngineCore pid=13461) INFO 05-25 19:07:44 [backends.py:1148] Dynamo bytecode transform time: 2.99 s
# (EngineCore pid=13461) INFO 05-25 19:07:45 [backends.py:292] Directly load the compiled graph(s) for compile range (1, 32768) from the cache, took 1.462 s
# (EngineCore pid=13461) INFO 05-25 19:07:45 [decorators.py:311] Directly load AOT compilation from path /tmp/xdg-cache/vllm/torch_compile_cache/torch_aot_compile/744fd9c0038c3601566849914db200e7f19a54aa5ec571c410c8464cff586f9e/rank_0_0/model
# (EngineCore pid=13461) INFO 05-25 19:07:45 [monitor.py:53] torch.compile took 4.80 s in total
# (EngineCore pid=13461) INFO 05-25 19:07:46 [monitor.py:81] Initial profiling/warmup run took 0.13 s
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140] EngineCore failed to start.
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140] Traceback (most recent call last):
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]   File "/home/prgowda/private/151B_SP26_Competition-main/.venv/lib/python3.14/site-packages/vllm/v1/engine/core.py", line 1114, in run_engine_core
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]     engine_core = EngineCoreProc(*args, engine_index=dp_rank, **kwargs)
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]   File "/home/prgowda/private/151B_SP26_Competition-main/.venv/lib/python3.14/site-packages/vllm/tracing/otel.py", line 178, in sync_wrapper
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]     return func(*args, **kwargs)
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]   File "/home/prgowda/private/151B_SP26_Competition-main/.venv/lib/python3.14/site-packages/vllm/v1/engine/core.py", line 880, in __init__
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]     super().__init__(
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]     ~~~~~~~~~~~~~~~~^
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]         vllm_config,
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]         ^^^^^^^^^^^^
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]     ...<3 lines>...
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]         internal_dp_balancing,
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]         ^^^^^^^^^^^^^^^^^^^^^^
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]     )
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]     ^
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]   File "/home/prgowda/private/151B_SP26_Competition-main/.venv/lib/python3.14/site-packages/vllm/v1/engine/core.py", line 128, in __init__
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]     kv_cache_config = self._initialize_kv_caches(vllm_config)
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]   File "/home/prgowda/private/151B_SP26_Competition-main/.venv/lib/python3.14/site-packages/vllm/tracing/otel.py", line 178, in sync_wrapper
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]     return func(*args, **kwargs)
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]   File "/home/prgowda/private/151B_SP26_Competition-main/.venv/lib/python3.14/site-packages/vllm/v1/engine/core.py", line 250, in _initialize_kv_caches
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]     available_gpu_memory = self.model_executor.determine_available_memory()
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]   File "/home/prgowda/private/151B_SP26_Competition-main/.venv/lib/python3.14/site-packages/vllm/v1/executor/abstract.py", line 147, in determine_available_memory
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]     return self.collective_rpc("determine_available_memory")
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]            ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]   File "/home/prgowda/private/151B_SP26_Competition-main/.venv/lib/python3.14/site-packages/vllm/v1/executor/uniproc_executor.py", line 93, in collective_rpc
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]     result = run_method(self.driver_worker, method, args, kwargs)
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]   File "/home/prgowda/private/151B_SP26_Competition-main/.venv/lib/python3.14/site-packages/vllm/v1/serial_utils.py", line 510, in run_method
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]     return func(*args, **kwargs)
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]   File "/home/prgowda/private/151B_SP26_Competition-main/.venv/lib/python3.14/site-packages/torch/utils/_contextlib.py", line 124, in decorate_context
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]     return func(*args, **kwargs)
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]   File "/home/prgowda/private/151B_SP26_Competition-main/.venv/lib/python3.14/site-packages/vllm/v1/worker/gpu_worker.py", line 392, in determine_available_memory
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]     self.model_runner.profile_run()
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]   File "/home/prgowda/private/151B_SP26_Competition-main/.venv/lib/python3.14/site-packages/vllm/v1/worker/gpu_model_runner.py", line 5955, in profile_run
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]     output = self._dummy_sampler_run(last_hidden_states)
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]   File "/home/prgowda/private/151B_SP26_Competition-main/.venv/lib/python3.14/site-packages/torch/utils/_contextlib.py", line 124, in decorate_context
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]     return func(*args, **kwargs)
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]   File "/home/prgowda/private/151B_SP26_Competition-main/.venv/lib/python3.14/site-packages/vllm/v1/worker/gpu_model_runner.py", line 5775, in _dummy_sampler_run
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]     raise e
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]   File "/home/prgowda/private/151B_SP26_Competition-main/.venv/lib/python3.14/site-packages/vllm/v1/worker/gpu_model_runner.py", line 5743, in _dummy_sampler_run
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]     sampler_output = self.sampler(
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]         logits=logits, sampling_metadata=dummy_metadata
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]     )
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]   File "/home/prgowda/private/151B_SP26_Competition-main/.venv/lib/python3.14/site-packages/torch/nn/modules/module.py", line 1779, in _wrapped_call_impl
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]     return self._call_impl(*args, **kwargs)
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]            ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]   File "/home/prgowda/private/151B_SP26_Competition-main/.venv/lib/python3.14/site-packages/torch/nn/modules/module.py", line 1790, in _call_impl
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]     return forward_call(*args, **kwargs)
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]   File "/home/prgowda/private/151B_SP26_Competition-main/.venv/lib/python3.14/site-packages/vllm/v1/sample/sampler.py", line 97, in forward
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]     sampled, processed_logprobs = self.sample(logits, sampling_metadata)
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]                                   ~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]   File "/home/prgowda/private/151B_SP26_Competition-main/.venv/lib/python3.14/site-packages/vllm/v1/sample/sampler.py", line 272, in sample
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]     random_sampled, processed_logprobs = self.topk_topp_sampler(
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]                                          ~~~~~~~~~~~~~~~~~~~~~~^
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]         logits,
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]         ^^^^^^^
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]     ...<2 lines>...
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]         sampling_metadata.top_p,
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]         ^^^^^^^^^^^^^^^^^^^^^^^^
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]     )
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]     ^
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]   File "/home/prgowda/private/151B_SP26_Competition-main/.venv/lib/python3.14/site-packages/torch/nn/modules/module.py", line 1779, in _wrapped_call_impl
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]     return self._call_impl(*args, **kwargs)
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]            ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]   File "/home/prgowda/private/151B_SP26_Competition-main/.venv/lib/python3.14/site-packages/torch/nn/modules/module.py", line 1790, in _call_impl
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]     return forward_call(*args, **kwargs)
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]   File "/home/prgowda/private/151B_SP26_Competition-main/.venv/lib/python3.14/site-packages/vllm/v1/sample/ops/topk_topp_sampler.py", line 157, in forward_cuda
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]     return flashinfer_sample(logits.contiguous(), k, p, generators), None
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]            ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]   File "/home/prgowda/private/151B_SP26_Competition-main/.venv/lib/python3.14/site-packages/vllm/v1/sample/ops/topk_topp_sampler.py", line 447, in flashinfer_sample
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]     next_token_ids = flashinfer.sampling.top_k_top_p_sampling_from_logits(
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]         logits, k, p, deterministic=True
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]     )
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]   File "/home/prgowda/private/151B_SP26_Competition-main/.venv/lib/python3.14/site-packages/flashinfer/sampling.py", line 1400, in top_k_top_p_sampling_from_logits
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]     masked_logits = top_k_mask_logits(logits, top_k)
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]   File "/home/prgowda/private/151B_SP26_Competition-main/.venv/lib/python3.14/site-packages/flashinfer/sampling.py", line 1806, in top_k_mask_logits
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]     return get_sampling_module().top_k_mask_logits(
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]            ~~~~~~~~~~~~~~~~~~~^^
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]   File "/home/prgowda/private/151B_SP26_Competition-main/.venv/lib/python3.14/site-packages/flashinfer/sampling.py", line 54, in get_sampling_module
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]     module = gen_sampling_module().build_and_load()
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]   File "/home/prgowda/private/151B_SP26_Competition-main/.venv/lib/python3.14/site-packages/flashinfer/jit/core.py", line 318, in build_and_load
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]     self.build(verbose, need_lock=False)
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]     ~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]   File "/home/prgowda/private/151B_SP26_Competition-main/.venv/lib/python3.14/site-packages/flashinfer/jit/core.py", line 303, in build
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]     self.write_ninja()
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]     ~~~~~~~~~~~~~~~~^^
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]   File "/home/prgowda/private/151B_SP26_Competition-main/.venv/lib/python3.14/site-packages/flashinfer/jit/core.py", line 274, in write_ninja
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]     content = generate_ninja_build_for_op(
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]         name=self.name,
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]     ...<5 lines>...
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]         needs_device_linking=self.needs_device_linking,
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]     )
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]   File "/home/prgowda/private/151B_SP26_Competition-main/.venv/lib/python3.14/site-packages/flashinfer/jit/cpp_ext.py", line 216, in generate_ninja_build_for_op
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]     cuda_home = get_cuda_path()
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]   File "/home/prgowda/private/151B_SP26_Competition-main/.venv/lib/python3.14/site-packages/flashinfer/jit/cpp_ext.py", line 61, in get_cuda_path
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]     raise RuntimeError(
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]         f"Could not find nvcc and default {cuda_home=} doesn't exist"
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140]     )
# (EngineCore pid=13461) ERROR 05-25 19:07:50 [core.py:1140] RuntimeError: Could not find nvcc and default cuda_home='/usr/local/cuda' doesn't exist
# (EngineCore pid=13461) Process EngineCore:
# (EngineCore pid=13461) Traceback (most recent call last):
# (EngineCore pid=13461)   File "/home/prgowda/.local/share/uv/python/cpython-3.14.5-linux-x86_64-gnu/lib/python3.14/multiprocessing/process.py", line 320, in _bootstrap
# (EngineCore pid=13461)     self.run()
# (EngineCore pid=13461)     ~~~~~~~~^^
# (EngineCore pid=13461)   File "/home/prgowda/.local/share/uv/python/cpython-3.14.5-linux-x86_64-gnu/lib/python3.14/multiprocessing/process.py", line 108, in run
# (EngineCore pid=13461)     self._target(*self._args, **self._kwargs)
# (EngineCore pid=13461)     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (EngineCore pid=13461)   File "/home/prgowda/private/151B_SP26_Competition-main/.venv/lib/python3.14/site-packages/vllm/v1/engine/core.py", line 1144, in run_engine_core
# (EngineCore pid=13461)     raise e
# (EngineCore pid=13461)   File "/home/prgowda/private/151B_SP26_Competition-main/.venv/lib/python3.14/site-packages/vllm/v1/engine/core.py", line 1114, in run_engine_core
# (EngineCore pid=13461)     engine_core = EngineCoreProc(*args, engine_index=dp_rank, **kwargs)
# (EngineCore pid=13461)   File "/home/prgowda/private/151B_SP26_Competition-main/.venv/lib/python3.14/site-packages/vllm/tracing/otel.py", line 178, in sync_wrapper
# (EngineCore pid=13461)     return func(*args, **kwargs)
# (EngineCore pid=13461)   File "/home/prgowda/private/151B_SP26_Competition-main/.venv/lib/python3.14/site-packages/vllm/v1/engine/core.py", line 880, in __init__
# (EngineCore pid=13461)     super().__init__(
# (EngineCore pid=13461)     ~~~~~~~~~~~~~~~~^
# (EngineCore pid=13461)         vllm_config,
# (EngineCore pid=13461)         ^^^^^^^^^^^^
# (EngineCore pid=13461)     ...<3 lines>...
# (EngineCore pid=13461)         internal_dp_balancing,
# (EngineCore pid=13461)         ^^^^^^^^^^^^^^^^^^^^^^
# (EngineCore pid=13461)     )
# (EngineCore pid=13461)     ^
# (EngineCore pid=13461)   File "/home/prgowda/private/151B_SP26_Competition-main/.venv/lib/python3.14/site-packages/vllm/v1/engine/core.py", line 128, in __init__
# (EngineCore pid=13461)     kv_cache_config = self._initialize_kv_caches(vllm_config)
# (EngineCore pid=13461)   File "/home/prgowda/private/151B_SP26_Competition-main/.venv/lib/python3.14/site-packages/vllm/tracing/otel.py", line 178, in sync_wrapper
# (EngineCore pid=13461)     return func(*args, **kwargs)
# (EngineCore pid=13461)   File "/home/prgowda/private/151B_SP26_Competition-main/.venv/lib/python3.14/site-packages/vllm/v1/engine/core.py", line 250, in _initialize_kv_caches
# (EngineCore pid=13461)     available_gpu_memory = self.model_executor.determine_available_memory()
# (EngineCore pid=13461)   File "/home/prgowda/private/151B_SP26_Competition-main/.venv/lib/python3.14/site-packages/vllm/v1/executor/abstract.py", line 147, in determine_available_memory
# (EngineCore pid=13461)     return self.collective_rpc("determine_available_memory")
# (EngineCore pid=13461)            ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (EngineCore pid=13461)   File "/home/prgowda/private/151B_SP26_Competition-main/.venv/lib/python3.14/site-packages/vllm/v1/executor/uniproc_executor.py", line 93, in collective_rpc
# (EngineCore pid=13461)     result = run_method(self.driver_worker, method, args, kwargs)
# (EngineCore pid=13461)   File "/home/prgowda/private/151B_SP26_Competition-main/.venv/lib/python3.14/site-packages/vllm/v1/serial_utils.py", line 510, in run_method
# (EngineCore pid=13461)     return func(*args, **kwargs)
# (EngineCore pid=13461)   File "/home/prgowda/private/151B_SP26_Competition-main/.venv/lib/python3.14/site-packages/torch/utils/_contextlib.py", line 124, in decorate_context
# (EngineCore pid=13461)     return func(*args, **kwargs)
# (EngineCore pid=13461)   File "/home/prgowda/private/151B_SP26_Competition-main/.venv/lib/python3.14/site-packages/vllm/v1/worker/gpu_worker.py", line 392, in determine_available_memory
# (EngineCore pid=13461)     self.model_runner.profile_run()
# (EngineCore pid=13461)     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^
# (EngineCore pid=13461)   File "/home/prgowda/private/151B_SP26_Competition-main/.venv/lib/python3.14/site-packages/vllm/v1/worker/gpu_model_runner.py", line 5955, in profile_run
# (EngineCore pid=13461)     output = self._dummy_sampler_run(last_hidden_states)
# (EngineCore pid=13461)   File "/home/prgowda/private/151B_SP26_Competition-main/.venv/lib/python3.14/site-packages/torch/utils/_contextlib.py", line 124, in decorate_context
# (EngineCore pid=13461)     return func(*args, **kwargs)
# (EngineCore pid=13461)   File "/home/prgowda/private/151B_SP26_Competition-main/.venv/lib/python3.14/site-packages/vllm/v1/worker/gpu_model_runner.py", line 5775, in _dummy_sampler_run
# (EngineCore pid=13461)     raise e
# (EngineCore pid=13461)   File "/home/prgowda/private/151B_SP26_Competition-main/.venv/lib/python3.14/site-packages/vllm/v1/worker/gpu_model_runner.py", line 5743, in _dummy_sampler_run
# (EngineCore pid=13461)     sampler_output = self.sampler(
# (EngineCore pid=13461)         logits=logits, sampling_metadata=dummy_metadata
# (EngineCore pid=13461)     )
# (EngineCore pid=13461)   File "/home/prgowda/private/151B_SP26_Competition-main/.venv/lib/python3.14/site-packages/torch/nn/modules/module.py", line 1779, in _wrapped_call_impl
# (EngineCore pid=13461)     return self._call_impl(*args, **kwargs)
# (EngineCore pid=13461)            ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
# (EngineCore pid=13461)   File "/home/prgowda/private/151B_SP26_Competition-main/.venv/lib/python3.14/site-packages/torch/nn/modules/module.py", line 1790, in _call_impl
# (EngineCore pid=13461)     return forward_call(*args, **kwargs)
# (EngineCore pid=13461)   File "/home/prgowda/private/151B_SP26_Competition-main/.venv/lib/python3.14/site-packages/vllm/v1/sample/sampler.py", line 97, in forward
# (EngineCore pid=13461)     sampled, processed_logprobs = self.sample(logits, sampling_metadata)
# (EngineCore pid=13461)                                   ~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (EngineCore pid=13461)   File "/home/prgowda/private/151B_SP26_Competition-main/.venv/lib/python3.14/site-packages/vllm/v1/sample/sampler.py", line 272, in sample
# (EngineCore pid=13461)     random_sampled, processed_logprobs = self.topk_topp_sampler(
# (EngineCore pid=13461)                                          ~~~~~~~~~~~~~~~~~~~~~~^
# (EngineCore pid=13461)         logits,
# (EngineCore pid=13461)         ^^^^^^^
# (EngineCore pid=13461)     ...<2 lines>...
# (EngineCore pid=13461)         sampling_metadata.top_p,
# (EngineCore pid=13461)         ^^^^^^^^^^^^^^^^^^^^^^^^
# (EngineCore pid=13461)     )
# (EngineCore pid=13461)     ^
# (EngineCore pid=13461)   File "/home/prgowda/private/151B_SP26_Competition-main/.venv/lib/python3.14/site-packages/torch/nn/modules/module.py", line 1779, in _wrapped_call_impl
# (EngineCore pid=13461)     return self._call_impl(*args, **kwargs)
# (EngineCore pid=13461)            ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
# (EngineCore pid=13461)   File "/home/prgowda/private/151B_SP26_Competition-main/.venv/lib/python3.14/site-packages/torch/nn/modules/module.py", line 1790, in _call_impl
# (EngineCore pid=13461)     return forward_call(*args, **kwargs)
# (EngineCore pid=13461)   File "/home/prgowda/private/151B_SP26_Competition-main/.venv/lib/python3.14/site-packages/vllm/v1/sample/ops/topk_topp_sampler.py", line 157, in forward_cuda
# (EngineCore pid=13461)     return flashinfer_sample(logits.contiguous(), k, p, generators), None
# (EngineCore pid=13461)            ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (EngineCore pid=13461)   File "/home/prgowda/private/151B_SP26_Competition-main/.venv/lib/python3.14/site-packages/vllm/v1/sample/ops/topk_topp_sampler.py", line 447, in flashinfer_sample
# (EngineCore pid=13461)     next_token_ids = flashinfer.sampling.top_k_top_p_sampling_from_logits(
# (EngineCore pid=13461)         logits, k, p, deterministic=True
# (EngineCore pid=13461)     )
# (EngineCore pid=13461)   File "/home/prgowda/private/151B_SP26_Competition-main/.venv/lib/python3.14/site-packages/flashinfer/sampling.py", line 1400, in top_k_top_p_sampling_from_logits
# (EngineCore pid=13461)     masked_logits = top_k_mask_logits(logits, top_k)
# (EngineCore pid=13461)   File "/home/prgowda/private/151B_SP26_Competition-main/.venv/lib/python3.14/site-packages/flashinfer/sampling.py", line 1806, in top_k_mask_logits
# (EngineCore pid=13461)     return get_sampling_module().top_k_mask_logits(
# (EngineCore pid=13461)            ~~~~~~~~~~~~~~~~~~~^^
# (EngineCore pid=13461)   File "/home/prgowda/private/151B_SP26_Competition-main/.venv/lib/python3.14/site-packages/flashinfer/sampling.py", line 54, in get_sampling_module
# (EngineCore pid=13461)     module = gen_sampling_module().build_and_load()
# (EngineCore pid=13461)   File "/home/prgowda/private/151B_SP26_Competition-main/.venv/lib/python3.14/site-packages/flashinfer/jit/core.py", line 318, in build_and_load
# (EngineCore pid=13461)     self.build(verbose, need_lock=False)
# (EngineCore pid=13461)     ~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^
# (EngineCore pid=13461)   File "/home/prgowda/private/151B_SP26_Competition-main/.venv/lib/python3.14/site-packages/flashinfer/jit/core.py", line 303, in build
# (EngineCore pid=13461)     self.write_ninja()
# (EngineCore pid=13461)     ~~~~~~~~~~~~~~~~^^
# (EngineCore pid=13461)   File "/home/prgowda/private/151B_SP26_Competition-main/.venv/lib/python3.14/site-packages/flashinfer/jit/core.py", line 274, in write_ninja
# (EngineCore pid=13461)     content = generate_ninja_build_for_op(
# (EngineCore pid=13461)         name=self.name,
# (EngineCore pid=13461)     ...<5 lines>...
# (EngineCore pid=13461)         needs_device_linking=self.needs_device_linking,
# (EngineCore pid=13461)     )
# (EngineCore pid=13461)   File "/home/prgowda/private/151B_SP26_Competition-main/.venv/lib/python3.14/site-packages/flashinfer/jit/cpp_ext.py", line 216, in generate_ninja_build_for_op
# (EngineCore pid=13461)     cuda_home = get_cuda_path()
# (EngineCore pid=13461)   File "/home/prgowda/private/151B_SP26_Competition-main/.venv/lib/python3.14/site-packages/flashinfer/jit/cpp_ext.py", line 61, in get_cuda_path
# (EngineCore pid=13461)     raise RuntimeError(
# (EngineCore pid=13461)         f"Could not find nvcc and default {cuda_home=} doesn't exist"
# (EngineCore pid=13461)     )
# (EngineCore pid=13461) RuntimeError: Could not find nvcc and default cuda_home='/usr/local/cuda' doesn't exist
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 4
#       1 tokenizer = AutoTokenizer.from_pretrained(MODEL_ID)
#       2 tokenizer.pad_token = tokenizer.eos_token
#       3
# ----> 4 llm = LLM(
#       5     model=MODEL_ID,
#       6     quantization="bitsandbytes",
#       7     load_format="bitsandbytes",
#
# File ~/private/151B_SP26_Competition-main/.venv/lib/python3.14/site-packages/vllm/entrypoints/llm.py:381, in LLM.__init__(self, model, runner, convert, tokenizer, tokenizer_mode, skip_tokenizer_init, trust_remote_code, allowed_local_media_path, allowed_media_domains, tensor_parallel_size, dtype, quantization, revision, tokenizer_revision, chat_template, seed, gpu_memory_utilization, cpu_offload_gb, offload_group_size, offload_num_in_group, offload_prefetch_step, offload_params, enforce_eager, enable_return_routed_experts, disable_custom_all_reduce, hf_token, hf_overrides, mm_processor_kwargs, pooler_config, structured_outputs_config, profiler_config, attention_config, kv_cache_memory_bytes, compilation_config, quantization_config, logits_processors, **kwargs)
#     340 engine_args = EngineArgs(
#     341     model=model,
#     342     runner=runner,
#    (...)    376     **kwargs,
#     377 )
#     379 log_non_default_args(engine_args)
# --> 381 self.llm_engine = LLMEngine.from_engine_args(
#     382     engine_args=engine_args, usage_context=UsageContext.LLM_CLASS
#     383 )
#     384 self.model_config = self.llm_engine.model_config
#     385 self.engine_class = type(self.llm_engine)
#
# File ~/private/151B_SP26_Competition-main/.venv/lib/python3.14/site-packages/vllm/v1/engine/llm_engine.py:170, in LLMEngine.from_engine_args(cls, engine_args, usage_context, stat_loggers, enable_multiprocessing)
#     167     enable_multiprocessing = True
#     169 # Create the LLMEngine.
# --> 170 return cls(
#     171     vllm_config=vllm_config,
#     172     executor_class=executor_class,
#     173     log_stats=not engine_args.disable_log_stats,
#     174     usage_context=usage_context,
#     175     stat_loggers=stat_loggers,
#     176     multiprocess_mode=enable_multiprocessing,
#     177 )
#
# File ~/private/151B_SP26_Competition-main/.venv/lib/python3.14/site-packages/vllm/v1/engine/llm_engine.py:104, in LLMEngine.__init__(self, vllm_config, executor_class, log_stats, aggregate_engine_logging, usage_context, stat_loggers, mm_registry, multiprocess_mode)
#      96 self.output_processor = OutputProcessor(
#      97     renderer.tokenizer,
#      98     log_stats=self.log_stats,
#      99     stream_interval=self.vllm_config.scheduler_config.stream_interval,
#     100     tracing_enabled=tracing_endpoint is not None,
#     101 )
#     103 # EngineCore (gets EngineCoreRequests and gives EngineCoreOutputs)
# --> 104 self.engine_core = EngineCoreClient.make_client(
#     105     multiprocess_mode=multiprocess_mode,
#     106     asyncio_mode=False,
#     107     vllm_config=vllm_config,
#     108     executor_class=executor_class,
#     109     log_stats=self.log_stats,
#     110 )
#     112 self.logger_manager: StatLoggerManager | None = None
#     113 if self.log_stats:
#
# File ~/private/151B_SP26_Competition-main/.venv/lib/python3.14/site-packages/vllm/v1/engine/core_client.py:101, in EngineCoreClient.make_client(multiprocess_mode, asyncio_mode, vllm_config, executor_class, log_stats)
#      96     return EngineCoreClient.make_async_mp_client(
#      97         vllm_config, executor_class, log_stats
#      98     )
#     100 if multiprocess_mode and not asyncio_mode:
# --> 101     return SyncMPClient(vllm_config, executor_class, log_stats)
#     103 return InprocClient(vllm_config, executor_class, log_stats)
#
# File ~/private/151B_SP26_Competition-main/.venv/lib/python3.14/site-packages/vllm/tracing/otel.py:178, in instrument_otel.<locals>.sync_wrapper(*args, **kwargs)
#     168 ctx = _get_smart_context()
#     169 with (
#     170     tracer.start_as_current_span(
#     171         final_span_name,
#    (...)    176     propagate_trace_to_env(),
#     177 ):
# --> 178     return func(*args, **kwargs)
#
# File ~/private/151B_SP26_Competition-main/.venv/lib/python3.14/site-packages/vllm/v1/engine/core_client.py:723, in SyncMPClient.__init__(self, vllm_config, executor_class, log_stats)
#     719 @instrument(span_name="SyncMPClient init")
#     720 def __init__(
#     721     self, vllm_config: VllmConfig, executor_class: type[Executor], log_stats: bool
#     722 ):
# --> 723     super().__init__(
#     724         asyncio_mode=False,
#     725         vllm_config=vllm_config,
#     726         executor_class=executor_class,
#     727         log_stats=log_stats,
#     728     )
#     730     self.is_dp = self.vllm_config.parallel_config.data_parallel_size > 1
#     731     self.outputs_queue = queue.Queue[EngineCoreOutputs | Exception]()
#
# File ~/private/151B_SP26_Competition-main/.venv/lib/python3.14/site-packages/vllm/v1/engine/core_client.py:535, in MPClient.__init__(self, asyncio_mode, vllm_config, executor_class, log_stats, client_addresses)
#     524 self.input_socket = self.resources.input_socket = make_zmq_socket(
#     525     self.ctx,
#     526     addresses.inputs[0],
#    (...)    529     router_handover=enable_input_socket_handover,
#     530 )
#     531 self.resources.output_socket = make_zmq_socket(
#     532     self.ctx, addresses.outputs[0], zmq.PULL
#     533 )
# --> 535 with launch_core_engines(
#     536     vllm_config, executor_class, log_stats, addresses
#     537 ) as (engine_manager, coordinator, addresses, tensor_queue):
#     538     self.resources.coordinator = coordinator
#     539     self.resources.engine_manager = engine_manager
#
# File ~/.local/share/uv/python/cpython-3.14.5-linux-x86_64-gnu/lib/python3.14/contextlib.py:148, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     146 if typ is None:
#     147     try:
# --> 148         next(self.gen)
#     149     except StopIteration:
#     150         return False
#
# File ~/private/151B_SP26_Competition-main/.venv/lib/python3.14/site-packages/vllm/v1/engine/utils.py:1128, in launch_core_engines(vllm_config, executor_class, log_stats, addresses, num_api_servers)
#    1125 yield local_engine_manager, coordinator, addresses, tensor_queue
#    1127 # Now wait for engines to start.
# -> 1128 wait_for_engine_startup(
#    1129     handshake_socket,
#    1130     addresses,
#    1131     engines_to_handshake,
#    1132     parallel_config,
#    1133     dp_size > 1 and vllm_config.model_config.is_moe,
#    1134     vllm_config.cache_config,
#    1135     local_engine_manager,
#    1136     coordinator.proc if coordinator else None,
#    1137 )
#
# File ~/private/151B_SP26_Competition-main/.venv/lib/python3.14/site-packages/vllm/v1/engine/utils.py:1187, in wait_for_engine_startup(handshake_socket, addresses, core_engines, parallel_config, coordinated_dp, cache_config, proc_manager, coord_process)
#    1185     if coord_process is not None and coord_process.exitcode is not None:
#    1186         finished[coord_process.name] = coord_process.exitcode
# -> 1187     raise RuntimeError(
#    1188         "Engine core initialization failed. "
#    1189         "See root cause above. "
#    1190         f"Failed core proc(s): {finished}"
#    1191     )
#    1193 # Receive HELLO and READY messages from the input socket.
#    1194 eng_identity, ready_msg_bytes = handshake_socket.recv_multipart()
#
# RuntimeError: Engine core initialization failed. See root cause above. Failed core proc(s): {}

# %% [markdown]
# ## 5. Load Model with Transformers (alternative to vLLM for DataHub)
#
# We load **Qwen3-4B-Thinking-2507** with **INT4 quantization** via BitsAndBytes.
#
# Key parameters:
# - `load_in_4bit` — quantization strategy of INT4

# %%
# import torch
# from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig


# import sys; print(sys.executable)


# MODEL_ID = "Qwen/Qwen3-4B-Thinking-2507"

# tokenizer = AutoTokenizer.from_pretrained(MODEL_ID)
# tokenizer.pad_token = tokenizer.eos_token

# bnb_config = BitsAndBytesConfig(
#     load_in_4bit=True,
#     bnb_4bit_compute_dtype=torch.bfloat16,
#     bnb_4bit_use_double_quant=True,
# )

# llm = AutoModelForCausalLM.from_pretrained(
#     MODEL_ID,
#     quantization_config=bnb_config,
#     device_map="auto",
# )

# %% [markdown]
# ## 6. Generate Responses
#
# We format every question into a chat-template prompt, then call `llm.generate()` in one batched pass.
# vLLM handles batching and scheduling internally — no manual batching needed.

# %% [markdown]
# ### Generate with vLLM

# %%
# Build prompts for first 5 entries
prompts = []
for item in data[:5]:
    system, user = build_prompt(item["question"], item.get("options"))
    prompt_text = tokenizer.apply_chat_template(
        [{"role": "system", "content": system},
         {"role": "user",   "content": user}],
        tokenize=False,
        add_generation_prompt=True,
    )
    prompts.append(prompt_text)

# Generate
print(f"Generating responses for {len(prompts)} questions...")
outputs = llm.generate(prompts, sampling_params=sampling_params)

responses = [out.outputs[0].text.strip() for out in outputs]

# Preview first 3
for i in range(min(3, len(responses))):
    print(f"\n── Response {i} (id={data[i].get('id')}) ──")
    print(responses[i][:400], "..." if len(responses[i]) > 400 else "")

# %% [markdown]
# ### Generate with Transformers (for Datahub)

# %%
# # Build prompts for first 5 entries
# prompts = []
# for item in data[:5]:
#     system, user = build_prompt(item["question"], item.get("options"))
#     prompt_text = tokenizer.apply_chat_template(
#         [{"role": "system", "content": system},
#          {"role": "user",   "content": user}],
#         tokenize=False,
#         add_generation_prompt=True,
#     )
#     prompts.append(prompt_text)

# # Tokenize (padded batch)
# print(f"Generating responses for {len(prompts)} questions...")
# inputs = tokenizer(
#     prompts,
#     return_tensors="pt",
#     padding=True,
#     truncation=True,
#     max_length=16384,
# ).to(llm.device)

# # Generate
# with torch.no_grad():
#     output_ids = llm.generate(
#         **inputs,
#         max_new_tokens=MAX_TOKENS,
#         temperature=0.6,
#         top_p=0.95,
#         top_k=20,
#         repetition_penalty=1.0,
#         do_sample=True,
#     )

# # Decode only the new tokens (strip the prompt)
# responses = []
# for i, out in enumerate(output_ids):
#     new_tokens = out[inputs["input_ids"].shape[1]:]
#     responses.append(tokenizer.decode(new_tokens, skip_special_tokens=True).strip())

# # Preview first 3
# for i in range(min(3, len(responses))):
#     print(f"\n── Response {i} (id={data[i].get('id')}) ──")
#     print(responses[i][:400], "..." if len(responses[i]) > 400 else "")

# %% [markdown]
# ## 7. Score Responses
#
# Scoring differs by question type:
#
# - **MCQ**: extract the predicted letter from `\boxed{}` and compare to the gold letter (exact match).
# - **Free-form**: use `Judger.auto_judge()` which handles symbolic and numeric equivalence.
#
# Each result record contains `{id, is_mcq, gold, response, correct}`.

# %%
def extract_letter(text: str) -> str:
    m = re.search(r"\\boxed\{([A-Za-z])\}", text)
    if m:
        return m.group(1).upper()
    matches = re.findall(r"\b([A-Z])\b", text.upper())
    return matches[-1] if matches else ""


def score_mcq(response: str, gold_letter: str) -> bool:
    return extract_letter(response) == gold_letter.strip().upper()


# Load Judger for free-form scoring
sys.path.insert(0, ".")
from judger import Judger
judger = Judger(strict_extract=False)

results = []
for item, response in tqdm(zip(data, responses), total=len(data), desc="Scoring"):
    is_mcq = bool(item.get("options"))
    gold   = item["answer"]

    if is_mcq:
        correct = score_mcq(response, str(gold))
    else:
        gold_list = gold if isinstance(gold, list) else [gold]
        try:
            correct = judger.auto_judge(
                pred=response,
                gold=gold_list,
                options=[[]] * len(gold_list),
            )
        except Exception:
            correct = False

    results.append({
        "id":       item.get("id"),
        "is_mcq":   is_mcq,
        "gold":     gold,
        "response": response,
        "correct":  correct,
    })

print(f"Scoring complete. {len(results)} results.")

# %% [markdown]
# ## 8. Summary
#
# Print accuracy broken down by question type.

# %%
mcq_res  = [r for r in results if r["is_mcq"]]
free_res = [r for r in results if not r["is_mcq"]]

def acc(subset):
    return sum(r["correct"] for r in subset) / len(subset) * 100 if subset else 0.0

print("=" * 50)
print("EVALUATION RESULTS")
print("=" * 50)
print(f"  MCQ        : {sum(r['correct'] for r in mcq_res):4d} / {len(mcq_res):4d}  ({acc(mcq_res):.2f}%)")
print(f"  Free-form  : {sum(r['correct'] for r in free_res):4d} / {len(free_res):4d}  ({acc(free_res):.2f}%)")
print(f"  Overall    : {sum(r['correct'] for r in results):4d} / {len(results):4d}  ({acc(results):.2f}%)")
print("=" * 50)

# %% [markdown]
# ## 9. Save Results
#
# Results are written as newline-delimited JSON.
#
# **With evaluation** (public set — you have ground-truth):
# Each line: `{id, is_mcq, gold, response, correct}`
#
# **Without evaluation** (private test set — no ground-truth available):
# Each line: `{id, is_mcq, response}` — omit `gold` and `correct`.
#
# Toggle `SAVE_EVAL` below accordingly.

# %%
SAVE_EVAL = True   # Set to False when running on the private test set

out_path = Path(OUTPUT_PATH)
out_path.parent.mkdir(parents=True, exist_ok=True)

with open(out_path, "w") as f:
    for r in results:
        if SAVE_EVAL:
            record = {"id": r["id"], "is_mcq": r["is_mcq"], "gold": r["gold"],
                      "response": r["response"], "correct": r["correct"]}
        else:
            record = {"id": r["id"], "is_mcq": r["is_mcq"], "response": r["response"]}
        f.write(json.dumps(record) + "\n")

print(f"Saved {len(results)} records to {out_path}")

# %% [markdown]
# ## Next Steps
#
# This notebook gives you a working baseline. Here are directions to improve your score:
#
# - **Prompt engineering** — try different system prompts or few-shot examples inside the user turn
# - **Sampling parameters** — adjust `temperature`, `top_p`, or use majority voting across multiple samples
# - **Fine-tuning** — the competition allows model fine-tuning; see the course resources for guidance
#
# Good luck!
